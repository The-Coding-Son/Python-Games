# %%
import random
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
class Card:
    
    def __init__(self,suit,rank):
        self.suit=suit
        self.rank=rank
        self.value=values[self.rank]
        
    def __str__(self):
        return f"{self.rank} of {self.suit}"

# %%
b=Card('Diamonds','Three')

# %%
print(b)
# Out:
# Three of Diamonds

# %%
b.value
# Out:
# 3

# %%
b.rank
# Out:
# 'Three'

# %%
b.suit
# Out:
# 'Diamonds'

# %%
class Deck:
    
    def __init__(self):
        
        self.all_cards=[]
        for suit in range(4):
            for rank in range(13):
                self.all_cards.append(Card(suits[suit],ranks[rank]))
    def shuffle(self):
        random.shuffle(self.all_cards)
    def Deal_One(self):
        return self.all_cards.pop(0)

# %%
class Player:
    
    def __init__(self,name):
        self.name=name
        self.all_cards=[]
        
    def __add_card__(self,card):
        if type(card)==type([]):
            self.all_cards.extend(card)
        else:
            self.all_cards.append(card)
            
    def __remove_card__(self):
        return self.all_cards.pop(0)
    def __len__(self):
        return f"{self.name} has {len(self.all_cards)} cards"

# %%
player1=Player("PLAYER ONE")  
player2=Player("PLAYER TWO")        
gameon=True    
mainDeck=Deck()
mainDeck.shuffle()
Round=0
player1turncards=[]
player2turncards=[]


for i in range(26):
    player1.__add_card__(mainDeck.Deal_One())
    player2.__add_card__(mainDeck.Deal_One())
            
while gameon:
    Round+=1 
    print(f"Round {Round}")
            
    if(len(player1.all_cards)==0):
        print("PLAYER ONE HAS LOST THE GAME!")
        print("PLAYER TWO WON! HURRAY!")
        gameon=False
        break      
    if(len(player2.all_cards)==0):
        print("PLAYER TWO HAS LOST THE GAME!")
        print("PLAYER ONE WON! HURRAY!")         
        gameon=False
        break      
    
                      
    player1turncards.append(player1.__remove_card__())
    player2turncards.append(player2.__remove_card__())
 
    if player1turncards[-1].value>player2turncards[-1].value:
        player1.__add_card__(player1turncards)
        player1.__add_card__(player2turncards)
        player1turncards=[]
        player2turncards=[]

    elif player1turncards[-1].value<player2turncards[-1].value:
        player2.__add_card__(player2turncards)
        player2.__add_card__(player1turncards)
        player1turncards=[]
        player2turncards=[]

    else :
        
        at_war=True      
                      
        while at_war:
            print("WAR!")
            if len(player1.all_cards) < 5:
                print("Player One unable to play war! Game Over at War")
                print("Player Two Wins! Player One Loses!")
                gameon = False
                break

            elif len(player2.all_cards) < 5:
                print("Player Two unable to play war! Game Over at War")
                print("Player One Wins! Player Two Loses!")
                gameon = False
                break
            # Otherwise, we're still at war, so we'll add the next cards
            else:
                for num in range(4):
                    player1turncards.append(player1.__remove_card__())
                    player2turncards.append(player2.__remove_card__())
               
            if player1turncards[-1].value==player2turncards[-1].value:
                at_war=True
            else:
                at_war=False
                if player1turncards[-1].value>player2turncards[-1].value:
                    player1.__add_card__(player1turncards)
                    player1.__add_card__(player2turncards)
                    player1turncards=[]
                    player2turncards=[]

                    
                elif player1turncards[-1].value<player2turncards[-1].value:
                    player2.__add_card__(player2turncards)
                    player2.__add_card__(player1turncards)
                    player1turncards=[]
                    player2turncards=[]
# Out:
# Round 1
# Round 2
# Round 3
# Round 4
# Round 5
# Round 6
# Round 7
# Round 8
# Round 9
# Round 10
# Round 11
# Round 12
# Round 13
# Round 14
# Round 15
# Round 16
# Round 17
# Round 18
# Round 19
# Round 20
# Round 21
# Round 22
# Round 23
# Round 24
# Round 25
# Round 26
# Round 27
# Round 28
# Round 29
# Round 30
# Round 31
# Round 32
# Round 33
# Round 34
# Round 35
# Round 36
# Round 37
# Round 38
# Round 39
# Round 40
# Round 41
# Round 42
# WAR!
# WAR!
# WAR!
# Round 43
# Round 44
# Round 45
# Round 46
# Round 47
# Round 48
# Round 49
# Round 50
# Round 51
# WAR!
# Round 52
# Round 53
# Round 54
# Round 55
# Round 56
# WAR!
# Round 57
# Round 58
# Round 59
# Round 60
# WAR!
# Round 61
# Round 62
# Round 63
# Round 64
# Round 65
# Round 66
# Round 67
# Round 68
# Round 69
# Round 70
# Round 71
# Round 72
# WAR!
# Round 73
# Round 74
# Round 75
# Round 76
# Round 77
# Round 78
# Round 79
# Round 80
# Round 81
# Round 82
# Round 83
# Round 84
# Round 85
# Round 86
# Round 87
# ...

# %%
def game():
    for k in range(15):
        player1=Player("PLAYER ONE")  
        player2=Player("PLAYER TWO")        
        gameon=True    
        mainDeck=Deck()
        mainDeck.shuffle()
        Round=0
        player1turncards=[]
        player2turncards=[]


        for i in range(26):
            player1.__add_card__(mainDeck.Deal_One())
            player2.__add_card__(mainDeck.Deal_One())

        while gameon:
            Round+=1 


    
            if(len(player1.all_cards)==0):

                print("PLAYER TWO WON! HURRAY!")
                gameon=False
                break      
            if(len(player2.all_cards)==0):

                print("PLAYER ONE WON! HURRAY!")         
                gameon=False
                break      


            player1turncards.append(player1.__remove_card__())
            player2turncards.append(player2.__remove_card__())

            if player1turncards[-1].value>player2turncards[-1].value:
                player1.__add_card__(player1turncards)
                player1.__add_card__(player2turncards)
                player1turncards=[]
                player2turncards=[]

            elif player1turncards[-1].value<player2turncards[-1].value:
                player2.__add_card__(player2turncards)
                player2.__add_card__(player1turncards)
                player1turncards=[]
                player2turncards=[]

            else :

                at_war=True      

                while at_war:

                    if len(player1.all_cards) < 5:
                        print("Player One unable to play war! Game Over at War")
                        print("Player Two Wins! Player One Loses!")
                        gameon = False
                        break

                    elif len(player2.all_cards) < 5:
                        print("Player Two unable to play war! Game Over at War")
                        print("Player One Wins! Player Two Loses!")
                        gameon = False
                        break
                    # Otherwise, we're still at war, so we'll add the next cards
                    else:
                        for num in range(4):
                            player1turncards.append(player1.__remove_card__())
                            player2turncards.append(player2.__remove_card__())

                    if player1turncards[-1].value==player2turncards[-1].value:
                        at_war=True
                    else:
                        at_war=False
                        if player1turncards[-1].value>player2turncards[-1].value:
                            player1.__add_card__(player1turncards)
                            player1.__add_card__(player2turncards)
                            player1turncards=[]
                            player2turncards=[]

                        elif player1turncards[-1].value<player2turncards[-1].value:
                            player2.__add_card__(player2turncards)
                            player2.__add_card__(player1turncards)
                            player1turncards=[]
                            player2turncards=[]
        print(f"{Round} Rounds")

# %%
game()
# Out:
# PLAYER ONE WON! HURRAY!
# 215 Rounds
# Player Two unable to play war! Game Over at War
# Player One Wins! Player Two Loses!
# 474 Rounds
# Player One unable to play war! Game Over at War
# Player Two Wins! Player One Loses!
# 312 Rounds
# Player Two unable to play war! Game Over at War
# Player One Wins! Player Two Loses!
# 116 Rounds
# PLAYER TWO WON! HURRAY!
# 151 Rounds
# Player Two unable to play war! Game Over at War
# Player One Wins! Player Two Loses!
# 360 Rounds
# Player One unable to play war! Game Over at War
# Player Two Wins! Player One Loses!
# 94 Rounds
# PLAYER ONE WON! HURRAY!
# 43 Rounds
# PLAYER ONE WON! HURRAY!
# 107 Rounds
# Player One unable to play war! Game Over at War
# Player Two Wins! Player One Loses!
# 66 Rounds
# PLAYER TWO WON! HURRAY!
# 387 Rounds
# Player Two unable to play war! Game Over at War
# Player One Wins! Player Two Loses!
# 64 Rounds
# PLAYER ONE WON! HURRAY!
# 107 Rounds
# PLAYER ONE WON! HURRAY!
# 401 Rounds
# PLAYER ONE WON! HURRAY!
# ...
